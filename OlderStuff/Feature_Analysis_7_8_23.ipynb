# %%
import pandas as pd
import numpy as np

# %%
# import csv of imagej analyzed data
df = pd.read_csv("/content/drive/Shareddrives/Summer_2023_VCell_Ml/Summer 2023  Image analysis/param_scan_7-6-23/=7-6_analysis_CSV.csv")

df.head()
# Out:
#                             File_Name   avg_val  num_spots  total_coverage  \
# 0    Ba=-0.038,Da=0.0,Di=0.5,Ga=0.075   79.2727      724.0        0.326225
# 1   Ba=-0.038,Da=0.0,Di=0.5,Ga=0.1425  224.3437        1.0        0.923225
# 2     Ba=-0.038,Da=0.0,Di=0.5,Ga=0.21  241.8883        1.0        0.995425
# 3   Ba=-0.038,Da=0.0,Di=0.5,Gi=0.0227  239.9686        1.0        0.987525
# 4  Ba=-0.038,Da=0.0,Di=0.5,Gi=0.07135  135.4482       74.0        0.557400
#
#    avg_spot_size  spot_size_std  avg_circ  circ_std
# 0   1.126500e-08       0.000523  0.713834  0.291812
# 1   2.308062e-05       0.000000  0.541700  0.000000
# 2   2.488562e-05       0.000000  0.760000  0.000000
# 3   2.468813e-05       0.000000  0.739200  0.000000
# 4   1.883110e-07       0.060858  0.842827  0.243896

# %%
# indexed as[wt_value,min,middle,max]
Param_Vals = {"Ua":[0.03,0.0083,0.02265,0.037],"Ui":[0.07,0.045,0.1425,0.24],
          "Ga":[0.08, 0.075,0.1425,0.21],"Gi":[0.1,0.0227,0.07135,0.12],
          "Ba":[-0.12,-0.138,-0.088,-0.038],"Da":[0.01,0,0.0065,0.013],
          "Di":[0.5,1.75,3]}

Param_List = {"Ua": [], "Ui": [], "Ga": [], "Gi" :[], "Ba": [], "Da": [], "Di": []}

for name in df["File_Name"]: #iterate through al file names
  for param in Param_Vals.keys(): #iterate through all parameter names
    if param in name: #check if parameter name is in file name
      p_i = name.index(param) #get parameter name index
      k = p_i + 3 #index of first number value of parameter
      while k < len(name) and name[k] != ",": #iterate through file name until hitting a comma or the end
        k += 1
      Param_List[param].append(name[p_i+3:k]) #add that value to the parameter list index for that parameter
    else:
      Param_List[param].append(Param_Vals[param][0]) #if the parameter is not in the file name, add the wild-type value to the parameter list

# %%
j = 1
#adds columns for all parameters to the dataframe, can only run once per session
for i in Param_List.keys():
  df.insert(j, i, Param_List[i])
  j+=1
df
# Out:
#                                  File_Name       Ua      Ui      Ga       Gi  \
# 0         Ba=-0.038,Da=0.0,Di=0.5,Ga=0.075     0.03    0.07   0.075      0.1
# 1        Ba=-0.038,Da=0.0,Di=0.5,Ga=0.1425     0.03    0.07  0.1425      0.1
# 2          Ba=-0.038,Da=0.0,Di=0.5,Ga=0.21     0.03    0.07    0.21      0.1
# 3        Ba=-0.038,Da=0.0,Di=0.5,Gi=0.0227     0.03    0.07    0.08   0.0227
# 4       Ba=-0.038,Da=0.0,Di=0.5,Gi=0.07135     0.03    0.07    0.08  0.07135
# ...                                    ...      ...     ...     ...      ...
# 2830  Ga=0.21,Gi=0.12,Ua=0.02265,Ui=0.1425  0.02265  0.1425    0.21     0.12
# 2831    Ga=0.21,Gi=0.12,Ua=0.02265,Ui=0.24  0.02265    0.24    0.21     0.12
# 2832     Ga=0.21,Gi=0.12,Ua=0.037,Ui=0.045    0.037   0.045    0.21     0.12
# 2833    Ga=0.21,Gi=0.12,Ua=0.037,Ui=0.1425    0.037  0.1425    0.21     0.12
# 2834      Ga=0.21,Gi=0.12,Ua=0.037,Ui=0.24    0.037    0.24    0.21     0.12
#
#           Ba    Da   Di   avg_val  num_spots  total_coverage  avg_spot_size  \
# 0     -0.038   0.0  0.5   79.2727      724.0        0.326225   1.126500e-08
# 1     -0.038   0.0  0.5  224.3437        1.0        0.923225   2.308062e-05
# 2     -0.038   0.0  0.5  241.8883        1.0        0.995425   2.488562e-05
# 3     -0.038   0.0  0.5  239.9686        1.0        0.987525   2.468813e-05
# 4     -0.038   0.0  0.5  135.4482       74.0        0.557400   1.883110e-07
# ...      ...   ...  ...       ...        ...             ...            ...
# 2830   -0.12  0.01  0.5  255.0000        1.0        1.000000   2.500000e-05
# 2831   -0.12  0.01  0.5  255.0000        1.0        1.000000   2.500000e-05
# 2832   -0.12  0.01  0.5   26.2136       73.0        0.190450   6.522300e-08
# 2833   -0.12  0.01  0.5  197.0000        1.0        1.000000   2.500000e-05
# 2834   -0.12  0.01  0.5  197.0000        1.0        1.000000   2.500000e-05
#
#       spot_size_std  avg_circ  circ_std
# 0          0.000523  0.713834  0.291812
# 1          0.000000  0.541700  0.000000
# 2          0.000000  0.760000  0.000000
# 3          0.000000  0.739200  0.000000
# 4          0.060858  0.842827  0.243896
# ...             ...       ...       ...
# 2830       0.000000  0.790000  0.000000
# 2831       0.000000  0.790000  0.000000
# 2832       0.000883  0.954325  0.082575
# 2833       0.000000  0.790000  0.000000
# 2834       0.000000  0.790000  0.000000
#
# [2835 rows x 15 columns]

# %%
# df = df.drop(columns=["File_Name"]) #get rrif of File_Name column
df
# Out:
#            Ua      Ui      Ga       Gi     Ba    Da   Di   avg_val  num_spots  \
# 0     0.03000  0.0700  0.0750  0.10000 -0.038  0.00  0.5   79.2727      724.0
# 1     0.03000  0.0700  0.1425  0.10000 -0.038  0.00  0.5  224.3437        1.0
# 2     0.03000  0.0700  0.2100  0.10000 -0.038  0.00  0.5  241.8883        1.0
# 3     0.03000  0.0700  0.0800  0.02270 -0.038  0.00  0.5  239.9686        1.0
# 4     0.03000  0.0700  0.0800  0.07135 -0.038  0.00  0.5  135.4482       74.0
# ...       ...     ...     ...      ...    ...   ...  ...       ...        ...
# 2830  0.02265  0.1425  0.2100  0.12000 -0.120  0.01  0.5  255.0000        1.0
# 2831  0.02265  0.2400  0.2100  0.12000 -0.120  0.01  0.5  255.0000        1.0
# 2832  0.03700  0.0450  0.2100  0.12000 -0.120  0.01  0.5   26.2136       73.0
# 2833  0.03700  0.1425  0.2100  0.12000 -0.120  0.01  0.5  197.0000        1.0
# 2834  0.03700  0.2400  0.2100  0.12000 -0.120  0.01  0.5  197.0000        1.0
#
#       total_coverage  avg_spot_size  spot_size_std  avg_circ  circ_std
# 0           0.326225   1.126500e-08       0.000523  0.713834  0.291812
# 1           0.923225   2.308062e-05       0.000000  0.541700  0.000000
# 2           0.995425   2.488562e-05       0.000000  0.760000  0.000000
# 3           0.987525   2.468813e-05       0.000000  0.739200  0.000000
# 4           0.557400   1.883110e-07       0.060858  0.842827  0.243896
# ...              ...            ...            ...       ...       ...
# 2830        1.000000   2.500000e-05       0.000000  0.790000  0.000000
# 2831        1.000000   2.500000e-05       0.000000  0.790000  0.000000
# 2832        0.190450   6.522300e-08       0.000883  0.954325  0.082575
# 2833        1.000000   2.500000e-05       0.000000  0.790000  0.000000
# 2834        1.000000   2.500000e-05       0.000000  0.790000  0.000000
#
# [2835 rows x 14 columns]

# %%
df = df.astype(float) #change all values to floats

# %% [markdown]
# Building the model
#
# Adapted from

# %%
#create train test split and divide dataset into inputs and targets
from sklearn.model_selection import train_test_split
x = df[["avg_val","num_spots","total_coverage","avg_spot_size","spot_size_std","avg_circ","circ_std"]]
y = df[["Ua","Ui","Ga","Gi","Ba","Da","Di"]]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %%
#Train the decision tree
from sklearn.tree import DecisionTreeRegressor
clf = DecisionTreeRegressor(criterion = 'squared_error', max_depth=5)
clf = clf.fit(x_train,y_train)

# %%
clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 5,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
# do predictions with the test values
predictions = clf.predict(x_test)
predictions

# %%
# analyze model performance
from sklearn import metrics
from sklearn.metrics import r2_score
# print('Mean Squared Error:', metrics.mean_squared_error(y_test,predictions)) # MSE
# print('R Squared Score is:', r2_score(y_test, predictions)) #R^2
# for importance, name in sorted(zip(clf.feature_importances_, x_train.columns),reverse=True): #Most important features
#  print (name, importance)

# %%
# Visualize Tree

from sklearn import tree
import graphviz
dot_data = tree.export_graphviz(clf, feature_names=list(x), class_names=sorted(y), filled=True)
graphviz.Source(dot_data)

# %% [markdown]
# Test with a random example

# %%
wt_df = pd.DataFrame({"avg_val":[7.1611] ,"num_spots":[83.0] ,"total_coverage":[0.056249999999999994],
                      "avg_spot_size":[float(1.6942771084337348e-08)] ,"spot_size_std": [0.00011525326016563174],"avg_circ":[0.9659421686746988] ,"circ_std":[0.04273925742706969]})


wt_prediction = clf.predict(wt_df)
wt_prediction

# %%
ds_df = pd.DataFrame({"avg_val":[25] ,"num_spots":[20] ,"total_coverage":[0.3],
                      "avg_spot_size":[float(1.6942771084337348e-06)] ,"spot_size_std": [0.00011525326016563174],"avg_circ":[0.9659421686746988] ,"circ_std":[0.04273925742706969]})


ds_prediction = clf.predict(ds_df)
ds_prediction

# %% [markdown]
# Random Forest Model

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(x_train, y_train);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(x_test)
# Calculate the absolute errors
errors = abs(predictions - y_test)
# Print out the mean absolute error (mae)
# print('Mean Absolute Error:')
# print(round(np.mean(errors), 5))

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / abs(y_test))
print("ImageJ Features")
print("Mean Absolute Percent Error")
print(round(np.mean(mape),5), "%")
# Calculate and display accuracy
# accuracy = 100 - np.mean(mape)
# print('Accuracy:', round(accuracy, 5), '%.')
# Out:
# ImageJ Features
# Mean Absolute Percent Error
# Ua    28.18734
# Ui    48.15144
# Ga    30.53853
# Gi    61.60818
# Ba    43.09743
# Da         inf
# Di    71.47780
# dtype: float64 %
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#WT Prediction
wt_df = pd.DataFrame({"avg_val":[7.1611] ,"num_spots":[83.0] ,"total_coverage":[0.056249999999999994],
                      "avg_spot_size":[float(1.6942771084337348e-08)] ,"spot_size_std": [0.00011525326016563174],"avg_circ":[0.9659421686746988] ,"circ_std":[0.04273925742706969]})


wt_prediction = rf.predict(wt_df)
wt_prediction
